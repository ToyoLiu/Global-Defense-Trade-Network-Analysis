# %%
import networkx as nx
from neo4j import GraphDatabase
import matplotlib.pyplot as plt

# %% [markdown]
# 连接Neo4j

# %%
class Neo4jConnection:
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)

    def close(self):
        if self.__driver is not None:
            self.__driver.close()

    def query(self, query, parameters=None, db=None):
        session = None
        response = None
        try:
            session = self.__driver.session(database=db) if db is not None else self.__driver.session()
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally:
            if session is not None:
                session.close()
        return response

neo4j_conn = Neo4jConnection(uri="bolt://localhost:7687/", user="neo4j", pwd="zxysxtc233")

# %% [markdown]
# 使用NetworkX建立图

# %%
query = """
MATCH (n)-[r]->(m)
RETURN n.name AS nName, ID(n) AS nId, m.name AS mName, ID(m) AS mId, r
"""
results = neo4j_conn.query(query)

results
# Out:
# Failed to write data to connection IPv4Address(('localhost', 7687)) (ResolvedIPv4Address(('127.0.0.1', 7687)))
# [<Record nName='(multiple sellers)' nId=0 mName='Brazil' mId=29 r=<Relationship element_id='8267' nodes=(<Node element_id='0' labels=frozenset() properties={}>, <Node element_id='29' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2019', 'num_delivered': 'Pending', 'weapon_description': 'BVRAAM', 'designation': 'Meteor', 'delivery_year': 'Pending'}>>,
#  <Record nName='Albania' nId=4 mName='Burkina Faso' mId=32 r=<Relationship element_id='0' nodes=(<Node element_id='4' labels=frozenset() properties={}>, <Node element_id='32' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2011', 'num_delivered': '12', 'weapon_description': 'Mortar', 'designation': 'M-43 120mm', 'delivery_year': '2011'}>>,
#  <Record nName='Algeria' nId=5 mName='Angola' mId=7 r=<Relationship element_id='1' nodes=(<Node element_id='5' labels=frozenset() properties={}>, <Node element_id='7' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1980', 'num_delivered': '4', 'weapon_description': 'Transport aircraft', 'designation': 'N-262 Fregate', 'delivery_year': '1980'}>>,
#  <Record nName='Algeria' nId=5 mName='Nigeria' mId=162 r=<Relationship element_id='2' nodes=(<Node element_id='5' labels=frozenset() properties={}>, <Node element_id='162' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1967', 'num_delivered': '2', 'weapon_description': 'Bomber aircraft', 'designation': 'Il-28', 'delivery_year': '1968'}>>,
#  <Record nName='Algeria' nId=5 mName='Western Sahara' mId=258 r=<Relationship element_id='3' nodes=(<Node element_id='5' labels=frozenset() properties={}>, <Node element_id='258' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2016', 'num_delivered': '3', 'weapon_description': 'APC', 'designation': 'BTR-60PB', 'delivery_year': '2016'}>>,
#  <Record nName='Angola' nId=7 mName='Congo' mId=44 r=<Relationship element_id='4' nodes=(<Node element_id='7' labels=frozenset() properties={}>, <Node element_id='44' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1979', 'num_delivered': '1', 'weapon_description': 'Transport aircraft', 'designation': 'Noratlas', 'delivery_year': '1979'}>>,
#  <Record nName='Angola' nId=7 mName='Cote dIvoire' mId=47 r=<Relationship element_id='5' nodes=(<Node element_id='7' labels=frozenset() properties={}>, <Node element_id='47' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2002', 'num_delivered': '2', 'weapon_description': 'IFV', 'designation': 'BMP-2', 'delivery_year': '2002'}>>,
#  <Record nName='Angola' nId=7 mName='Cote dIvoire' mId=47 r=<Relationship element_id='6' nodes=(<Node element_id='7' labels=frozenset() properties={}>, <Node element_id='47' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2002', 'num_delivered': '2', 'weapon_description': 'Tank', 'designation': 'T-55', 'delivery_year': '2002'}>>,
#  <Record nName='Angola' nId=7 mName='Guinea-Bissau' mId=88 r=<Relationship element_id='7' nodes=(<Node element_id='7' labels=frozenset() properties={}>, <Node element_id='88' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1980', 'num_delivered': '1', 'weapon_description': 'Light aircraft', 'designation': 'Do-27', 'delivery_year': '1980'}>>,
#  <Record nName='Angola' nId=7 mName='United States' mId=245 r=<Relationship element_id='8' nodes=(<Node element_id='7' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1992', 'num_delivered': '250', 'weapon_description': 'Portable SAM', 'designation': 'FIM-92 Stinger', 'delivery_year': '1992'}>>,
#  <Record nName='Argentina' nId=9 mName='Bolivia' mId=26 r=<Relationship element_id='9' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='26' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2006', 'num_delivered': '37', 'weapon_description': 'APC', 'designation': 'M-3/M-5 Half-track', 'delivery_year': '2006'}>>,
#  <Record nName='Argentina' nId=9 mName='Colombia' mId=42 r=<Relationship element_id='10' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='42' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1989', 'num_delivered': '3', 'weapon_description': 'Ground attack ac', 'designation': 'IA-58A Pucara', 'delivery_year': '1990'}>>,
#  <Record nName='Argentina' nId=9 mName='Denmark' mId=55 r=<Relationship element_id='11' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='55' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1987', 'num_delivered': '1', 'weapon_description': 'ASW helicopter', 'designation': 'Lynx', 'delivery_year': '1987'}>>,
#  <Record nName='Argentina' nId=9 mName='Denmark' mId=55 r=<Relationship element_id='12' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='55' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1988', 'num_delivered': '3', 'weapon_description': 'Turboshaft', 'designation': 'Gem', 'delivery_year': '1988'}>>,
#  <Record nName='Argentina' nId=9 mName='Ecuador' mId=61 r=<Relationship element_id='13' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='61' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1995', 'num_delivered': '18', 'weapon_description': 'Towed gun', 'designation': 'M-101A1 105mm', 'delivery_year': '1995'}>>,
#  <Record nName='Argentina' nId=9 mName='Honduras' mId=94 r=<Relationship element_id='14' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='94' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1980', 'num_delivered': '60', 'weapon_description': 'Mortar', 'designation': 'MO-120-M65 120mm', 'delivery_year': '1981-1983'}>>,
#  <Record nName='Argentina' nId=9 mName='Paraguay' mId=180 r=<Relationship element_id='15' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='180' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1962', 'num_delivered': '3', 'weapon_description': 'Transport aircraft', 'designation': 'CV-440', 'delivery_year': '1962'}>>,
#  <Record nName='Argentina' nId=9 mName='Paraguay' mId=180 r=<Relationship element_id='16' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='180' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1964', 'num_delivered': '3', 'weapon_description': 'OPV', 'designation': 'Bouchard', 'delivery_year': '1964-1968'}>>,
#  <Record nName='Argentina' nId=9 mName='Paraguay' mId=180 r=<Relationship element_id='17' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='180' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1966', 'num_delivered': '1', 'weapon_description': 'Light transport ac', 'designation': 'G-21 Goose', 'delivery_year': '1967'}>>,
#  <Record nName='Argentina' nId=9 mName='Paraguay' mId=180 r=<Relationship element_id='18' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='180' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1970', 'num_delivered': '1', 'weapon_description': 'Light transport ac', 'designation': 'DHC-3 Otter', 'delivery_year': '1972'}>>,
#  <Record nName='Argentina' nId=9 mName='Paraguay' mId=180 r=<Relationship element_id='19' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='180' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1972', 'num_delivered': '1', 'weapon_description': 'Landing ship', 'designation': 'LSM', 'delivery_year': '1972'}>>,
#  <Record nName='Argentina' nId=9 mName='Paraguay' mId=180 r=<Relationship element_id='20' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='180' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1975', 'num_delivered': '10', 'weapon_description': 'Trainer aircraft', 'designation': 'T-6 Texan', 'delivery_year': '1976'}>>,
#  <Record nName='Argentina' nId=9 mName='Paraguay' mId=180 r=<Relationship element_id='21' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='180' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1979', 'num_delivered': '1', 'weapon_description': 'Transport aircraft', 'designation': 'DC-3/C-47 Skytrain', 'delivery_year': '1979'}>>,
#  <Record nName='Argentina' nId=9 mName='Paraguay' mId=180 r=<Relationship element_id='22' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='180' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1980', 'num_delivered': '3', 'weapon_description': 'Tank', 'designation': 'Firefly', 'delivery_year': '1980'}>>,
#  <Record nName='Argentina' nId=9 mName='Paraguay' mId=180 r=<Relationship element_id='23' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='180' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1982', 'num_delivered': '6', 'weapon_description': 'Tank', 'designation': 'M-4 Sherman', 'delivery_year': '1982'}>>,
#  <Record nName='Argentina' nId=9 mName='Paraguay' mId=180 r=<Relationship element_id='24' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='180' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2007', 'num_delivered': '20', 'weapon_description': 'APC', 'designation': 'M-3/M-5 Half-track', 'delivery_year': '2011'}>>,
#  <Record nName='Argentina' nId=9 mName='Spain' mId=217 r=<Relationship element_id='25' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='217' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2001', 'num_delivered': '1', 'weapon_description': 'Transport helicopter', 'designation': 'CH-47C Chinook', 'delivery_year': '2001'}>>,
#  <Record nName='Argentina' nId=9 mName='Sri Lanka' mId=218 r=<Relationship element_id='26' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='218' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1992', 'num_delivered': '4', 'weapon_description': 'Ground attack ac', 'designation': 'IA-58A Pucara', 'delivery_year': '1993-1994'}>>,
#  <Record nName='Argentina' nId=9 mName='Uruguay' mId=251 r=<Relationship element_id='27' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='251' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1969', 'num_delivered': '2', 'weapon_description': 'Trainer aircraft', 'designation': 'T-6 Texan', 'delivery_year': '1970'}>>,
#  <Record nName='Argentina' nId=9 mName='Uruguay' mId=251 r=<Relationship element_id='28' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='251' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1979', 'num_delivered': '3', 'weapon_description': 'Light transport ac', 'designation': 'Beech-18/C-45', 'delivery_year': '1979'}>>,
#  <Record nName='Argentina' nId=9 mName='Uruguay' mId=251 r=<Relationship element_id='29' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='251' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1979', 'num_delivered': '9', 'weapon_description': 'Trainer/combat ac', 'designation': 'T-28D', 'delivery_year': '1979'}>>,
#  <Record nName='Argentina' nId=9 mName='Uruguay' mId=251 r=<Relationship element_id='30' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='251' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1980', 'num_delivered': '6', 'weapon_description': 'Ground attack ac', 'designation': 'IA-58A Pucara', 'delivery_year': '1981'}>>,
#  <Record nName='Argentina' nId=9 mName='Uruguay' mId=251 r=<Relationship element_id='31' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='251' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1990', 'num_delivered': '1', 'weapon_description': 'Light transport ac', 'designation': 'PA-34 Seneca', 'delivery_year': '1991'}>>,
#  <Record nName='Argentina' nId=9 mName='Uruguay' mId=251 r=<Relationship element_id='32' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='251' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1993', 'num_delivered': '1', 'weapon_description': 'Light transport ac', 'designation': 'PA-34 Seneca', 'delivery_year': '1994'}>>,
#  <Record nName='Argentina' nId=9 mName='Uruguay' mId=251 r=<Relationship element_id='33' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='251' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2000', 'num_delivered': '1', 'weapon_description': 'Ground attack ac', 'designation': 'IA-58A Pucara', 'delivery_year': '2000'}>>,
#  <Record nName='Argentina' nId=9 mName='Uruguay' mId=251 r=<Relationship element_id='34' nodes=(<Node element_id='9' labels=frozenset() properties={}>, <Node element_id='251' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2002', 'num_delivered': '1', 'weapon_description': 'Ground attack ac', 'designation': 'IA-58A Pucara', 'delivery_year': '2002'}>>,
#  <Record nName='Armenia' nId=11 mName='Sudan' mId=219 r=<Relationship element_id='35' nodes=(<Node element_id='11' labels=frozenset() properties={}>, <Node element_id='219' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2005', 'num_delivered': '1', 'weapon_description': 'Transport aircraft', 'designation': 'An-32', 'delivery_year': '2006'}>>,
#  <Record nName='Aruba' nId=12 mName='Israel' mId=104 r=<Relationship element_id='36' nodes=(<Node element_id='12' labels=frozenset() properties={}>, <Node element_id='104' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1996', 'num_delivered': '1', 'weapon_description': 'Transport aircraft', 'designation': 'Boeing-707', 'delivery_year': '1996'}>>,
#  <Record nName='Australia' nId=13 mName='Lesotho' mId=124 r=<Relationship element_id='87' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='124' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2003', 'num_delivered': '1', 'weapon_description': 'Light aircraft', 'designation': 'GA-8 Airvan', 'delivery_year': '2004'}>>,
#  <Record nName='Australia' nId=13 mName='Yemen' mId=259 r=<Relationship element_id='164' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='259' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2003', 'num_delivered': '10', 'weapon_description': 'Patrol craft', 'designation': 'P-1022', 'delivery_year': '2005'}>>,
#  <Record nName='Australia' nId=13 mName='Vanuatu' mId=253 r=<Relationship element_id='163' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='253' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': 'Pending', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': 'Pending'}>>,
#  <Record nName='Australia' nId=13 mName='Vanuatu' mId=253 r=<Relationship element_id='162' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='253' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1985', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1987'}>>,
#  <Record nName='Australia' nId=13 mName='United States' mId=245 r=<Relationship element_id='161' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2011', 'num_delivered': '3', 'weapon_description': 'Tanker/transport ac', 'designation': 'KC-707', 'delivery_year': '2011'}>>,
#  <Record nName='Australia' nId=13 mName='United States' mId=245 r=<Relationship element_id='160' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2003', 'num_delivered': '1', 'weapon_description': 'Transport ship', 'designation': 'Incat', 'delivery_year': '2003'}>>,
#  <Record nName='Australia' nId=13 mName='United States' mId=245 r=<Relationship element_id='159' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2003', 'num_delivered': '7', 'weapon_description': 'Light aircraft', 'designation': 'GA-8 Airvan', 'delivery_year': '2004'}>>,
#  <Record nName='Australia' nId=13 mName='United States' mId=245 r=<Relationship element_id='158' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2002', 'num_delivered': '1', 'weapon_description': 'Transport ship', 'designation': 'Incat', 'delivery_year': '2002'}>>,
#  <Record nName='Australia' nId=13 mName='United States' mId=245 r=<Relationship element_id='157' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2001', 'num_delivered': '1', 'weapon_description': 'Transport ship', 'designation': 'WestPac Express', 'delivery_year': '2001'}>>,
#  <Record nName='Australia' nId=13 mName='United States' mId=245 r=<Relationship element_id='156' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2001', 'num_delivered': '1', 'weapon_description': 'Transport ship', 'designation': 'Incat', 'delivery_year': '2001'}>>,
#  <Record nName='Australia' nId=13 mName='United States' mId=245 r=<Relationship element_id='155' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1991', 'num_delivered': '7', 'weapon_description': 'Transport helicopter', 'designation': 'CH-47C Chinook', 'delivery_year': '1994-1995'}>>,
#  <Record nName='Australia' nId=13 mName='United States' mId=245 r=<Relationship element_id='154' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1985', 'num_delivered': '7', 'weapon_description': 'Transport aircraft', 'designation': 'Boeing-707', 'delivery_year': '1986-1987'}>>,
#  <Record nName='Australia' nId=13 mName='United Kingdom' mId=243 r=<Relationship element_id='153' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='243' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2008', 'num_delivered': '24', 'weapon_description': 'APC', 'designation': 'Bushmaster', 'delivery_year': '2008'}>>,
#  <Record nName='Australia' nId=13 mName='United Kingdom' mId=243 r=<Relationship element_id='152' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='243' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1960', 'num_delivered': '400', 'weapon_description': 'Anti-tank missile', 'designation': 'Malkara-1', 'delivery_year': '1961-1962'}>>,
#  <Record nName='Australia' nId=13 mName='United Kingdom' mId=243 r=<Relationship element_id='151' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='243' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1955', 'num_delivered': '1', 'weapon_description': 'Support ship', 'designation': 'Tide', 'delivery_year': '1955'}>>,
#  <Record nName='Australia' nId=13 mName='Tuvalu' mId=236 r=<Relationship element_id='150' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='236' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': '2019'}>>,
#  <Record nName='Australia' nId=13 mName='Tuvalu' mId=236 r=<Relationship element_id='149' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='236' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1992', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1994'}>>,
#  <Record nName='Australia' nId=13 mName='Trinidad and Tobago' mId=232 r=<Relationship element_id='148' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='232' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2019', 'num_delivered': 'Pending', 'weapon_description': 'Patrol craft', 'designation': 'Cape', 'delivery_year': 'Pending'}>>,
#  <Record nName='Australia' nId=13 mName='Trinidad and Tobago' mId=232 r=<Relationship element_id='147' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='232' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2008', 'num_delivered': '6', 'weapon_description': 'Patrol craft', 'designation': 'Austal-30m', 'delivery_year': '2010'}>>,
#  <Record nName='Australia' nId=13 mName='Tonga' mId=231 r=<Relationship element_id='146' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='231' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': '2019'}>>,
#  <Record nName='Australia' nId=13 mName='Tonga' mId=231 r=<Relationship element_id='145' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='231' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': '1', 'weapon_description': 'Landing craft', 'designation': 'Forgacs 30m', 'delivery_year': '2015'}>>,
#  <Record nName='Australia' nId=13 mName='Tonga' mId=231 r=<Relationship element_id='144' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='231' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1988', 'num_delivered': '3', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1989-1991'}>>,
#  <Record nName='Australia' nId=13 mName='Timor-Leste' mId=229 r=<Relationship element_id='143' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='229' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2017', 'num_delivered': 'Pending', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': 'Pending'}>>,
#  <Record nName='Australia' nId=13 mName='Thailand' mId=228 r=<Relationship element_id='142' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='228' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1984', 'num_delivered': '1', 'weapon_description': 'MP aircraft', 'designation': 'Nomad Searchmaster-L', 'delivery_year': '1985'}>>,
#  <Record nName='Australia' nId=13 mName='Thailand' mId=228 r=<Relationship element_id='141' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='228' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1983', 'num_delivered': '6', 'weapon_description': 'Light transport ac', 'designation': 'Nomad', 'delivery_year': '1984'}>>,
#  <Record nName='Australia' nId=13 mName='Thailand' mId=228 r=<Relationship element_id='140' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='228' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1981', 'num_delivered': '21', 'weapon_description': 'Light transport ac', 'designation': 'Nomad', 'delivery_year': '1982-1984'}>>,
#  <Record nName='Australia' nId=13 mName='Sweden' mId=221 r=<Relationship element_id='139' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='221' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2003', 'num_delivered': '2', 'weapon_description': 'Transport aircraft', 'designation': 'Saab-340', 'delivery_year': '2003'}>>,
#  <Record nName='Australia' nId=13 mName='Sri Lanka' mId=218 r=<Relationship element_id='138' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='218' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': '2', 'weapon_description': 'Patrol craft', 'designation': 'Bay', 'delivery_year': '2014'}>>,
#  <Record nName='Australia' nId=13 mName='Solomon Islands' mId=208 r=<Relationship element_id='137' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='208' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': '2019'}>>,
#  <Record nName='Australia' nId=13 mName='Solomon Islands' mId=208 r=<Relationship element_id='136' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='208' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1989', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1991'}>>,
#  <Record nName='Australia' nId=13 mName='Solomon Islands' mId=208 r=<Relationship element_id='135' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='208' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1985', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1988'}>>,
#  <Record nName='Australia' nId=13 mName='Singapore' mId=205 r=<Relationship element_id='134' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='205' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2012', 'num_delivered': '35', 'weapon_description': 'IFV turret', 'designation': 'R-600', 'delivery_year': '2012-2013'}>>,
#  <Record nName='Australia' nId=13 mName='Singapore' mId=205 r=<Relationship element_id='133' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='205' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2009', 'num_delivered': '100', 'weapon_description': 'IFV turret', 'designation': 'R-600', 'delivery_year': '2010-2011'}>>,
#  <Record nName='Australia' nId=13 mName='Samoa' mId=199 r=<Relationship element_id='132' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='199' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': '2019'}>>,
#  <Record nName='Australia' nId=13 mName='Samoa' mId=199 r=<Relationship element_id='131' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='199' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1985', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1988'}>>,
#  <Record nName='Australia' nId=13 mName='Philippines' mId=183 r=<Relationship element_id='130' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='183' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2015', 'num_delivered': '3', 'weapon_description': 'Landing craft', 'designation': 'Balikpapan', 'delivery_year': '2016'}>>,
#  <Record nName='Australia' nId=13 mName='Philippines' mId=183 r=<Relationship element_id='129' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='183' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2015', 'num_delivered': '2', 'weapon_description': 'Landing craft', 'designation': 'Balikpapan', 'delivery_year': '2015'}>>,
#  <Record nName='Australia' nId=13 mName='Philippines' mId=183 r=<Relationship element_id='128' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='183' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1989', 'num_delivered': '3', 'weapon_description': 'Light transport ac', 'designation': 'Nomad', 'delivery_year': '1990'}>>,
#  <Record nName='Australia' nId=13 mName='Philippines' mId=183 r=<Relationship element_id='127' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='183' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1979', 'num_delivered': '1', 'weapon_description': 'Light transport ac', 'designation': 'Nomad', 'delivery_year': '1980'}>>,
#  <Record nName='Australia' nId=13 mName='Philippines' mId=183 r=<Relationship element_id='126' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='183' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1974', 'num_delivered': '11', 'weapon_description': 'Light transport ac', 'designation': 'Nomad', 'delivery_year': '1975-1976'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='125' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': '2018'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='124' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': '1', 'weapon_description': 'Landing craft', 'designation': 'Balikpapan', 'delivery_year': '2014'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='123' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1989', 'num_delivered': '4', 'weapon_description': 'Helicopter', 'designation': 'Bell-205/UH-1H', 'delivery_year': '1990'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='122' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1985', 'num_delivered': '4', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1987-1989'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='121' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1983', 'num_delivered': '1', 'weapon_description': 'MP aircraft', 'designation': 'Nomad Searchmaster-B', 'delivery_year': '1984'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='120' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1980', 'num_delivered': '2', 'weapon_description': 'MP aircraft', 'designation': 'Nomad Searchmaster-B', 'delivery_year': '1982'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='119' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1980', 'num_delivered': '2', 'weapon_description': 'Transport aircraft', 'designation': 'DC-3/C-47 Skytrain', 'delivery_year': '1981'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='118' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1977', 'num_delivered': '3', 'weapon_description': 'Light transport ac', 'designation': 'Nomad', 'delivery_year': '1977-1978'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='117' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1975', 'num_delivered': '2', 'weapon_description': 'Landing craft', 'designation': 'Balikpapan', 'delivery_year': '1975'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='116' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1975', 'num_delivered': '5', 'weapon_description': 'Patrol craft', 'designation': 'Attack', 'delivery_year': '1975'}>>,
#  <Record nName='Australia' nId=13 mName='Papua New Guinea' mId=179 r=<Relationship element_id='115' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='179' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1974', 'num_delivered': '4', 'weapon_description': 'Transport aircraft', 'designation': 'DC-3/C-47 Skytrain', 'delivery_year': '1975'}>>,
#  <Record nName='Australia' nId=13 mName='Palau' mId=176 r=<Relationship element_id='114' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='176' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': 'Pending', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': 'Pending'}>>,
#  <Record nName='Australia' nId=13 mName='Palau' mId=176 r=<Relationship element_id='113' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='176' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1995', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1996'}>>,
#  <Record nName='Australia' nId=13 mName='Pakistan' mId=175 r=<Relationship element_id='112' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='175' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1990', 'num_delivered': '45', 'weapon_description': 'FGA aircraft', 'designation': 'Mirage-3E', 'delivery_year': '1990-1991'}>>,
#  <Record nName='Australia' nId=13 mName='Oman' mId=169 r=<Relationship element_id='111' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='169' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': '2', 'weapon_description': 'Transport ship', 'designation': 'HSSV-72', 'delivery_year': '2016'}>>,
#  <Record nName='Australia' nId=13 mName='New Zealand' mId=159 r=<Relationship element_id='110' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='159' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2015', 'num_delivered': '5', 'weapon_description': 'APC', 'designation': 'Bushmaster', 'delivery_year': '2018'}>>,
#  <Record nName='Australia' nId=13 mName='New Zealand' mId=159 r=<Relationship element_id='109' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='159' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': 'Pending', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': 'Pending'}>>,
#  <Record nName='Australia' nId=13 mName='New Zealand' mId=159 r=<Relationship element_id='108' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='159' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2013', 'num_delivered': '20', 'weapon_description': 'Anti-ship missile', 'designation': 'Penguin-2', 'delivery_year': '2014-2015'}>>,
#  <Record nName='Australia' nId=13 mName='New Zealand' mId=159 r=<Relationship element_id='107' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='159' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1988', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1989'}>>,
#  <Record nName='Australia' nId=13 mName='New Zealand' mId=159 r=<Relationship element_id='106' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='159' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1984', 'num_delivered': '10', 'weapon_description': 'FGA aircraft', 'designation': 'A-4E Skyhawk', 'delivery_year': '1984'}>>,
#  <Record nName='Australia' nId=13 mName='New Zealand' mId=159 r=<Relationship element_id='105' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='159' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1952', 'num_delivered': '4', 'weapon_description': 'Minesweeper/corvette', 'designation': 'Bathurst', 'delivery_year': '1952'}>>,
#  <Record nName='Australia' nId=13 mName='Netherlands' mId=158 r=<Relationship element_id='104' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='158' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2016', 'num_delivered': '8', 'weapon_description': 'APC', 'designation': 'Bushmaster', 'delivery_year': '2017'}>>,
#  <Record nName='Australia' nId=13 mName='Netherlands' mId=158 r=<Relationship element_id='103' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='158' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2015', 'num_delivered': '12', 'weapon_description': 'APC', 'designation': 'Bushmaster', 'delivery_year': '2016-2017'}>>,
#  <Record nName='Australia' nId=13 mName='Netherlands' mId=158 r=<Relationship element_id='102' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='158' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2009', 'num_delivered': '14', 'weapon_description': 'APC', 'designation': 'Bushmaster', 'delivery_year': '2009'}>>,
#  <Record nName='Australia' nId=13 mName='Netherlands' mId=158 r=<Relationship element_id='101' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='158' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2009', 'num_delivered': '9', 'weapon_description': 'APC', 'designation': 'Bushmaster', 'delivery_year': '2009'}>>,
#  <Record nName='Australia' nId=13 mName='Netherlands' mId=158 r=<Relationship element_id='100' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='158' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2009', 'num_delivered': '14', 'weapon_description': 'APC', 'designation': 'Bushmaster', 'delivery_year': '2009'}>>,
#  <Record nName='Australia' nId=13 mName='Netherlands' mId=158 r=<Relationship element_id='99' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='158' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2008', 'num_delivered': '13', 'weapon_description': 'APC', 'designation': 'Bushmaster', 'delivery_year': '2008'}>>,
#  <Record nName='Australia' nId=13 mName='Netherlands' mId=158 r=<Relationship element_id='98' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='158' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2007', 'num_delivered': '11', 'weapon_description': 'APC', 'designation': 'Bushmaster', 'delivery_year': '2007-2008'}>>,
#  <Record nName='Australia' nId=13 mName='Netherlands' mId=158 r=<Relationship element_id='97' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='158' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2006', 'num_delivered': '25', 'weapon_description': 'APC', 'designation': 'Bushmaster', 'delivery_year': '2006'}>>,
#  <Record nName='Australia' nId=13 mName='Netherlands' mId=158 r=<Relationship element_id='96' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='158' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1962', 'num_delivered': '2', 'weapon_description': 'Transport aircraft', 'designation': 'DC-3/C-47 Skytrain', 'delivery_year': '1962'}>>,
#  <Record nName='Australia' nId=13 mName='Nepal' mId=157 r=<Relationship element_id='95' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='157' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1970', 'num_delivered': '2', 'weapon_description': 'Transport aircraft', 'designation': 'DC-3/C-47 Skytrain', 'delivery_year': '1971'}>>,
#  <Record nName='Australia' nId=13 mName='Micronesia' mId=145 r=<Relationship element_id='94' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='145' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': 'Pending', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': 'Pending'}>>,
#  <Record nName='Australia' nId=13 mName='Micronesia' mId=145 r=<Relationship element_id='93' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='145' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1997', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1997'}>>,
#  <Record nName='Australia' nId=13 mName='Micronesia' mId=145 r=<Relationship element_id='92' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='145' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1989', 'num_delivered': '2', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1990'}>>,
#  <Record nName='Australia' nId=13 mName='Marshall Islands' mId=141 r=<Relationship element_id='91' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='141' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2014', 'num_delivered': 'Pending', 'weapon_description': 'Patrol craft', 'designation': 'Guardian', 'delivery_year': 'Pending'}>>,
#  <Record nName='Australia' nId=13 mName='Marshall Islands' mId=141 r=<Relationship element_id='90' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='141' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1989', 'num_delivered': '1', 'weapon_description': 'Patrol craft', 'designation': 'ASI-315', 'delivery_year': '1991'}>>,
#  <Record nName='Australia' nId=13 mName='Malaysia' mId=137 r=<Relationship element_id='89' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='137' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1970', 'num_delivered': '6', 'weapon_description': 'Fighter aircraft', 'designation': 'F-86F Sabre', 'delivery_year': '1971'}>>,
#  <Record nName='Australia' nId=13 mName='Malaysia' mId=137 r=<Relationship element_id='88' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='137' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1969', 'num_delivered': '10', 'weapon_description': 'Fighter aircraft', 'designation': 'F-86F Sabre', 'delivery_year': '1969'}>>,
#  <Record nName='Australia' nId=13 mName='India' mId=98 r=<Relationship element_id='37' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='98' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2004', 'num_delivered': '11', 'weapon_description': 'Patrol craft', 'designation': 'Thornycroft 26m', 'delivery_year': '2006-2011'}>>,
#  <Record nName='Australia' nId=13 mName='Jordan' mId=108 r=<Relationship element_id='38' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='108' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2006', 'num_delivered': '6', 'weapon_description': 'Light aircraft', 'designation': 'SB7L-360 Seeker', 'delivery_year': '2006'}>>,
#  <Record nName='Australia' nId=13 mName='Malaysia' mId=137 r=<Relationship element_id='39' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='137' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2000', 'num_delivered': '3', 'weapon_description': 'UAV/light aircraft', 'designation': 'Eagle-ARV', 'delivery_year': '2001'}>>,
#  <Record nName='Australia' nId=13 mName='New Zealand' mId=159 r=<Relationship element_id='40' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='159' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2004', 'num_delivered': '2', 'weapon_description': 'OPV', 'designation': 'Tenix-1600', 'delivery_year': '2010'}>>,
#  <Record nName='Australia' nId=13 mName='New Zealand' mId=159 r=<Relationship element_id='41' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='159' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2004', 'num_delivered': '4', 'weapon_description': 'Patrol craft', 'designation': 'Tenix-340', 'delivery_year': '2009'}>>,
#  <Record nName='Australia' nId=13 mName='United Kingdom' mId=243 r=<Relationship element_id='42' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='243' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1970', 'num_delivered': '600', 'weapon_description': 'ASW missile', 'designation': 'Ikara', 'delivery_year': '1973-1977'}>>,
#  <Record nName='Australia' nId=13 mName='United Kingdom' mId=243 r=<Relationship element_id='43' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='243' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1977', 'num_delivered': '77', 'weapon_description': 'ASW missile', 'designation': 'Ikara', 'delivery_year': '1977-1982'}>>,
#  <Record nName='Australia' nId=13 mName='United States' mId=245 r=<Relationship element_id='44' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2008', 'num_delivered': '1', 'weapon_description': 'Transport ship', 'designation': 'EPF', 'delivery_year': '2012'}>>,
#  <Record nName='Australia' nId=13 mName='United States' mId=245 r=<Relationship element_id='45' nodes=(<Node element_id='13' labels=frozenset() properties={}>, <Node element_id='245' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2009', 'num_delivered': '10', 'weapon_description': 'Transport ship', 'designation': 'EPF', 'delivery_year': '2013-2019'}>>,
# ...
#  <Record nName='Canada' nId=37 mName='Mexico' mId=144 r=<Relationship element_id='1002' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='144' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2006', 'num_delivered': '2', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2006'}>>,
#  <Record nName='Canada' nId=37 mName='Mexico' mId=144 r=<Relationship element_id='1001' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='144' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2000', 'num_delivered': '1', 'weapon_description': 'Transport aircraft', 'designation': 'Dash-8', 'delivery_year': '2002'}>>,
#  <Record nName='Canada' nId=37 mName='Mexico' mId=144 r=<Relationship element_id='1000' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='144' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1985', 'num_delivered': '33', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '1986-1992'}>>,
#  <Record nName='Canada' nId=37 mName='Mexico' mId=144 r=<Relationship element_id='999' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='144' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1985', 'num_delivered': '9', 'weapon_description': 'MP aircraft radar', 'designation': 'APS-504(V)', 'delivery_year': '1986-1987'}>>,
#  <Record nName='Canada' nId=37 mName='Mexico' mId=144 r=<Relationship element_id='998' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='144' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1981', 'num_delivered': '17', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '1982-1983'}>>,
#  <Record nName='Canada' nId=37 mName='Mexico' mId=144 r=<Relationship element_id='997' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='144' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1979', 'num_delivered': '3', 'weapon_description': 'Transport aircraft', 'designation': 'DHC-5 Buffalo', 'delivery_year': '1980'}>>,
#  <Record nName='Canada' nId=37 mName='Mexico' mId=144 r=<Relationship element_id='996' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='144' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1978', 'num_delivered': '38', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '1979-1981'}>>,
#  <Record nName='Canada' nId=37 mName='Mexico' mId=144 r=<Relationship element_id='995' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='144' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1975', 'num_delivered': '4', 'weapon_description': 'MP/transport ac', 'designation': 'HU-16B Albatross', 'delivery_year': '1976'}>>,
#  <Record nName='Canada' nId=37 mName='Mexico' mId=144 r=<Relationship element_id='994' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='144' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1960', 'num_delivered': '3', 'weapon_description': 'Trainer aircraft', 'designation': 'Vampire T-55', 'delivery_year': '1961'}>>,
#  <Record nName='Canada' nId=37 mName='Mexico' mId=144 r=<Relationship element_id='993' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='144' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1960', 'num_delivered': '12', 'weapon_description': 'Fighter aircraft', 'designation': 'Vampire F-3', 'delivery_year': '1961'}>>,
#  <Record nName='Canada' nId=37 mName='Mauritania' mId=142 r=<Relationship element_id='992' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='142' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2011', 'num_delivered': '2', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2012'}>>,
#  <Record nName='Canada' nId=37 mName='Mauritania' mId=142 r=<Relationship element_id='991' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='142' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1977', 'num_delivered': '2', 'weapon_description': 'Transport aircraft', 'designation': 'DHC-5 Buffalo', 'delivery_year': '1977-1978'}>>,
#  <Record nName='Canada' nId=37 mName='Mali' mId=139 r=<Relationship element_id='990' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='139' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2016', 'num_delivered': '2', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PW100', 'delivery_year': '2016'}>>,
#  <Record nName='Canada' nId=37 mName='Mali' mId=139 r=<Relationship element_id='989' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='139' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2015', 'num_delivered': '4', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2018'}>>,
#  <Record nName='Canada' nId=37 mName='Malaysia' mId=137 r=<Relationship element_id='988' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='137' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2013', 'num_delivered': '5', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2016'}>>,
#  <Record nName='Canada' nId=37 mName='Malaysia' mId=137 r=<Relationship element_id='987' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='137' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2006', 'num_delivered': '10', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2007'}>>,
#  <Record nName='Canada' nId=37 mName='Malaysia' mId=137 r=<Relationship element_id='986' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='137' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2000', 'num_delivered': '9', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2001'}>>,
#  <Record nName='Canada' nId=37 mName='Malaysia' mId=137 r=<Relationship element_id='985' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='137' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1981', 'num_delivered': '44', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '1982-1984'}>>,
#  <Record nName='Canada' nId=37 mName='Malaysia' mId=137 r=<Relationship element_id='984' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='137' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1968', 'num_delivered': '16', 'weapon_description': 'Transport aircraft', 'designation': 'DHC-4 Caribou', 'delivery_year': '1969-1972'}>>,
#  <Record nName='Canada' nId=37 mName='Malaysia' mId=137 r=<Relationship element_id='983' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='137' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1966', 'num_delivered': '20', 'weapon_description': 'Trainer/combat ac', 'designation': 'CL-41G Tutor', 'delivery_year': '1967-1969'}>>,
#  <Record nName='Canada' nId=37 mName='Malaysia' mId=137 r=<Relationship element_id='982' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='137' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1965', 'num_delivered': '4', 'weapon_description': 'Transport aircraft', 'designation': 'DHC-4 Caribou', 'delivery_year': '1966'}>>,
#  <Record nName='Canada' nId=37 mName='Lebanon' mId=122 r=<Relationship element_id='981' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='122' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2015', 'num_delivered': '8', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2017-2018'}>>,
#  <Record nName='Canada' nId=37 mName='Lebanon' mId=122 r=<Relationship element_id='980' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='122' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1949', 'num_delivered': '3', 'weapon_description': 'Trainer aircraft', 'designation': 'DHC-1 Chipmunk', 'delivery_year': '1950'}>>,
#  <Record nName='Canada' nId=37 mName='Laos' mId=120 r=<Relationship element_id='979' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='120' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2012', 'num_delivered': '4', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PW100', 'delivery_year': '2013'}>>,
#  <Record nName='Canada' nId=37 mName='Laos' mId=120 r=<Relationship element_id='978' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='120' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2010', 'num_delivered': '4', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PW100', 'delivery_year': '2012'}>>,
#  <Record nName='Canada' nId=37 mName='Kuwait' mId=115 r=<Relationship element_id='977' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='115' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1965', 'num_delivered': '2', 'weapon_description': 'Transport aircraft', 'designation': 'DHC-4 Caribou', 'delivery_year': '1966'}>>,
#  <Record nName='Canada' nId=37 mName='Kenya' mId=111 r=<Relationship element_id='976' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='111' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1989', 'num_delivered': '3', 'weapon_description': 'Transport aircraft', 'designation': 'Dash-8', 'delivery_year': '1990'}>>,
#  <Record nName='Canada' nId=37 mName='Kenya' mId=111 r=<Relationship element_id='975' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='111' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1986', 'num_delivered': '4', 'weapon_description': 'Transport aircraft', 'designation': 'DHC-5 Buffalo', 'delivery_year': '1986-1987'}>>,
#  <Record nName='Canada' nId=37 mName='Kenya' mId=111 r=<Relationship element_id='974' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='111' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1976', 'num_delivered': '6', 'weapon_description': 'Transport aircraft', 'designation': 'DHC-5 Buffalo', 'delivery_year': '1977-1978'}>>,
#  <Record nName='Canada' nId=37 mName='Kenya' mId=111 r=<Relationship element_id='973' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='111' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1970', 'num_delivered': '2', 'weapon_description': 'Transport aircraft', 'designation': 'DHC-4 Caribou', 'delivery_year': '1972'}>>,
#  <Record nName='Canada' nId=37 mName='Kenya' mId=111 r=<Relationship element_id='972' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='111' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1966', 'num_delivered': '8', 'weapon_description': 'Light aircraft', 'designation': 'DHC-2 Beaver', 'delivery_year': '1966'}>>,
#  <Record nName='Canada' nId=37 mName='Kenya' mId=111 r=<Relationship element_id='971' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='111' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1964', 'num_delivered': '4', 'weapon_description': 'Transport aircraft', 'designation': 'DHC-4 Caribou', 'delivery_year': '1965'}>>,
#  <Record nName='Canada' nId=37 mName='Kenya' mId=111 r=<Relationship element_id='970' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='111' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '1964', 'num_delivered': '3', 'weapon_description': 'Light aircraft', 'designation': 'DHC-2 Beaver', 'delivery_year': '1964'}>>,
#  <Record nName='Canada' nId=37 mName='Kazakhstan' mId=110 r=<Relationship element_id='969' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='110' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2017', 'num_delivered': '4', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PW100', 'delivery_year': '2017'}>>,
#  <Record nName='Canada' nId=37 mName='Kazakhstan' mId=110 r=<Relationship element_id='968' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='110' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2015', 'num_delivered': '4', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PW100', 'delivery_year': '2016'}>>,
#  <Record nName='Canada' nId=37 mName='Kazakhstan' mId=110 r=<Relationship element_id='967' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='110' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2013', 'num_delivered': '4', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PW100', 'delivery_year': '2014'}>>,
#  <Record nName='Canada' nId=37 mName='Kazakhstan' mId=110 r=<Relationship element_id='966' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='110' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2012', 'num_delivered': '4', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PW100', 'delivery_year': '2013'}>>,
#  <Record nName='Canada' nId=37 mName='Jordan' mId=108 r=<Relationship element_id='965' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='108' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2017', 'num_delivered': '2', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2018'}>>,
#  <Record nName='Canada' nId=37 mName='Jordan' mId=108 r=<Relationship element_id='964' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='108' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2016', 'num_delivered': '2', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2018'}>>,
#  <Record nName='Canada' nId=37 mName='Jordan' mId=108 r=<Relationship element_id='963' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='108' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2015', 'num_delivered': '4', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2016'}>>,
#  <Record nName='Canada' nId=37 mName='Jordan' mId=108 r=<Relationship element_id='962' nodes=(<Node element_id='37' labels=frozenset() properties={}>, <Node element_id='108' labels=frozenset() properties={}>) type='supplied' properties={'order_year': '2015', 'num_delivered': '8', 'weapon_description': 'Turboprop/turboshaft', 'designation': 'PT6', 'delivery_year': '2017'}>>,
#  ...]

# %%
import csv
import os 

csv_file_path = "graph_data/total.csv"
csv_dir = os.path.dirname(csv_file_path)

if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Source", "Target"])
    for record in results:
        writer.writerow([record["nName"], record["mName"]])

# %%
G = nx.MultiDiGraph()

# 添加节点和边
for record in results:
    n_id = record["nId"]
    m_id = record["mId"]
    n_name = record["nName"]
    m_name = record["mName"]
    r_attributes = dict(record["r"].items())  # 假设r是一个包含属性的Neo4j Record对象

    # 添加节点，使用节点的name属性作为标签
    G.add_node(n_id, label=n_name)
    G.add_node(m_id, label=m_name)

    # 添加边，标签设为"supplied"
    G.add_edge(n_id, m_id, label="supplied", **r_attributes)

# 关闭Neo4j连接
neo4j_conn.close()

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (265, 26631)

# %% [markdown]
# 度排序

# %%
# 计算所有节点的入度和出度
in_degrees = dict(G.in_degree())
out_degrees = dict(G.out_degree())

# 按入度降序排序节点，并获取前10个
top_10_in_degrees = sorted(in_degrees, key=in_degrees.get, reverse=True)[:10]
# 按出度降序排序节点，并获取前10个
top_10_out_degrees = sorted(out_degrees, key=out_degrees.get, reverse=True)[:10]

# 获取这些节点的name，id和度数
# 注意这里将 'name' 改为 'label' 以匹配你实际设置的属性键
top_10_in_degrees_info = [(node, G.nodes[node]['label'], in_degrees[node]) for node in top_10_in_degrees]
top_10_out_degrees_info = [(node, G.nodes[node]['label'], out_degrees[node]) for node in top_10_out_degrees]

# %%
# 输出入度最高的10个节点的信息
for info in top_10_in_degrees_info:
    print(f"Node ID: {info[0]}, Name: {info[1]}, In-Degree: {info[2]}")
# Out:
# Node ID: 98, Name: India, In-Degree: 718
# Node ID: 62, Name: Egypt, In-Degree: 615
# Node ID: 228, Name: Thailand, In-Degree: 562
# Node ID: 234, Name: Turkey, In-Degree: 559
# Node ID: 84, Name: Greece, In-Degree: 541
# Node ID: 99, Name: Indonesia, In-Degree: 502
# Node ID: 200, Name: Saudi Arabia, In-Degree: 501
# Node ID: 175, Name: Pakistan, In-Degree: 486
# Node ID: 211, Name: South Korea, In-Degree: 474
# Node ID: 102, Name: Iraq, In-Degree: 456

# %%
# 输出出度最高的10个节点的信息
for info in top_10_out_degrees_info:
    print(f"Node ID: {info[0]}, Name: {info[1]}, Out-Degree: {info[2]}")
# Out:
# Node ID: 245, Name: United States, Out-Degree: 8612
# Node ID: 216, Name: Soviet Union, Out-Degree: 3358
# Node ID: 77, Name: France, Out-Degree: 2407
# Node ID: 243, Name: United Kingdom, Out-Degree: 1904
# Node ID: 82, Name: Germany, Out-Degree: 1201
# Node ID: 192, Name: Russia, Out-Degree: 1129
# Node ID: 105, Name: Italy, Out-Degree: 924
# Node ID: 41, Name: China, Out-Degree: 903
# Node ID: 104, Name: Israel, Out-Degree: 642
# Node ID: 158, Name: Netherlands, Out-Degree: 554

# %% [markdown]
# PageRank

# %%
pagerank = nx.pagerank(G)

pagerank_with_labels = {G.nodes[node_id]['label']: rank for node_id, rank in pagerank.items()}

pagerank_with_labels
# Out:
# {'(multiple sellers)': 0.0017038623514746575,
#  'Brazil': 0.006563376252882768,
#  'Albania': 0.002005952775740612,
#  'Burkina Faso': 0.011517865385026332,
#  'Algeria': 0.004687070434797691,
#  'Angola': 0.012460969893983766,
#  'Nigeria': 0.00919227745679946,
#  'Western Sahara': 0.0032810856308873293,
#  'Congo': 0.005540990041216654,
#  'Cote dIvoire': 0.006564229877324563,
#  'Guinea-Bissau': 0.004277630058426135,
#  'United States': 0.013795768205557666,
#  'Argentina': 0.007836115698814372,
#  'Bolivia': 0.01702980156336316,
#  'Colombia': 0.005651722166824771,
#  'Denmark': 0.004587380590387571,
#  'Ecuador': 0.008364494547996058,
#  'Honduras': 0.005059589003778422,
#  'Paraguay': 0.006744272096863903,
#  'Spain': 0.005606090311907688,
#  'Sri Lanka': 0.0064250147366245215,
#  'Uruguay': 0.0145407649873836,
#  'Armenia': 0.0020360887953068062,
#  'Sudan': 0.010956686250908005,
#  'Aruba': 0.0017038623514746575,
#  'Israel': 0.005505853178727605,
#  'Australia': 0.004671550884446459,
#  'Lesotho': 0.0019432271108291868,
#  'Yemen': 0.0037721396015650064,
#  'Vanuatu': 0.001765912849503022,
#  'United Kingdom': 0.010543735387419793,
#  'Tuvalu': 0.001765912849503022,
#  'Trinidad and Tobago': 0.0018197936268708834,
#  'Tonga': 0.0018902023807494566,
#  'Timor-Leste': 0.0017660035261768577,
#  'Thailand': 0.008787629790843207,
#  'Sweden': 0.0050708120874933225,
#  'Solomon Islands': 0.0017969380985172043,
#  'Singapore': 0.012640110187029213,
#  'Samoa': 0.001765912849503022,
#  'Philippines': 0.008269589119451358,
#  'Papua New Guinea': 0.002660450520772933,
#  'Palau': 0.0017672745301227479,
#  'Pakistan': 0.011626032659358935,
#  'Oman': 0.0063962361990901485,
#  'New Zealand': 0.002810908267696417,
#  'Netherlands': 0.0033437207844591353,
#  'Nepal': 0.003912635667561434,
#  'Micronesia': 0.00179829977913693,
#  'Marshall Islands': 0.0017672745301227479,
#  'Malaysia': 0.009531975041901244,
#  'India': 0.01163171346233907,
#  'Jordan': 0.013374131424415845,
#  'Brunei': 0.0026403298448424727,
#  'Cambodia': 0.007218758421023217,
#  'Canada': 0.0032504026678471538,
#  'Chad': 0.002543508059911309,
#  'Chile': 0.008653900621628213,
#  'Fiji': 0.0018068206796355865,
#  'Ghana': 0.010187088346306812,
#  'Indonesia': 0.009062473081620776,
#  'Iraq': 0.010905297824002937,
#  'Jamaica': 0.0018562457924284073,
#  'Japan': 0.0024333043083424634,
#  'Kiribati': 0.001765912849503022,
#  'Kuwait': 0.0035660003473838523,
#  'Laos': 0.004853034487512092,
#  'Austria': 0.002452227501172839,
#  'Italy': 0.002625907437581771,
#  'Yugoslavia': 0.00345833739281366,
#  'Venezuela': 0.0031087554494193454,
#  'Uganda': 0.0031345391995365023,
#  'Turkmenistan': 0.002808889596008316,
#  'Tunisia': 0.0025073595080464268,
#  'Saudi Arabia': 0.005417977992708397,
#  'Poland': 0.004235121310754272,
#  'OSCE**': 0.0017241002658915465,
#  'Niger': 0.0019876988473259065,
#  'Myanmar': 0.005296561284309092,
#  'Morocco': 0.004168032156418949,
#  'Montenegro': 0.0017645515833379713,
#  'Libya': 0.006638680883140071,
#  'Latvia': 0.002182638858584736,
#  'Belgium': 0.002960552302757632,
#  'Czechia': 0.0038309735549598356,
#  'Greece': 0.004330903996883481,
#  'Portugal': 0.002760206844187494,
#  'Slovenia': 0.001973708908198044,
#  'UAE': 0.007193678508436933,
#  'Bangladesh': 0.006681607764051748,
#  'Botswana': 0.003356403437829612,
#  'Egypt': 0.005648423432843476,
#  'France': 0.012067581195208808,
#  'Gabon': 0.006944539598117428,
#  'Germany': 0.003825883545626383,
#  'Iran': 0.008035215612657378,
#  'Bahamas': 0.0017404638453285923,
#  'Bahrain': 0.005275181984842298,
#  'Belarus': 0.0017573482866618307,
#  'Viet Nam': 0.0035715359981045324,
#  'Syria': 0.0050538034940262756,
#  'Sierra Leone': 0.0019225693401859307,
#  'Serbia': 0.0023032130740948133,
#  'Rwanda': 0.002123195101786891,
#  'Peru': 0.013745859864651098,
#  'Libya HoR': 0.0029227933929089154,
#  'Afghanistan': 0.004080849570955655,
#  'Azerbaijan': 0.003715884270232727,
#  'China': 0.0027310479445173358,
#  'Djibouti': 0.0031475604670521727,
#  'DR Congo': 0.009993453339247501,
#  'Eritrea': 0.002945338167548091,
#  'Ethiopia': 0.004437572046919132,
#  'Hungary': 0.0022946867630156366,
#  'Zimbabwe': 0.006298342395071805,
#  'United Nations**': 0.0021329484836746645,
#  'Turkey': 0.004749118910230995,
#  'Qatar': 0.0030068936801442804,
#  'Panama': 0.003421676081966725,
#  'Norway': 0.0027871814721214657,
#  'NATO**': 0.0018535695169015658,
#  'Mexico': 0.004751705623756602,
#  'Lebanon': 0.004444206815406042,
#  'Katanga': 0.0017824281161952177,
#  'Benin': 0.010955543395024402,
#  'Bulgaria': 0.002450019555400927,
#  'Estonia': 0.00233133838627268,
#  'Bosnia-Herzegovina': 0.002769238142940116,
#  'Cameroon': 0.0032817068871475144,
#  'Comoros': 0.0017601428269480033,
#  'Unknown recipient(s)': 0.0026870600705582934,
#  'Togo': 0.0022606518423126764,
#  'Suriname': 0.003532637059779577,
#  'South Korea': 0.003190167885539934,
#  'Namibia': 0.0026622868377142953,
#  'Mozambique': 0.0030692244141371193,
#  'Mauritania': 0.0038767379055410305,
#  'Mali': 0.004380371960788292,
#  'Guyana': 0.005104407630552976,
#  'Dominican Republic': 0.0024031869626091667,
#  'Cyprus': 0.005640067789058055,
#  'Cabo Verde': 0.0034158663175236207,
#  'Georgia': 0.003543634039480424,
#  'Tajikistan': 0.001755541745044093,
#  'Soviet Union': 0.007317467301467279,
#  'Southern rebels (Yemen)*': 0.001982007242153724,
#  'Senegal': 0.005446509383660612,
#  'Romania': 0.002535237171824224,
#  'Nicaragua': 0.009582054064433524,
#  'Macedonia': 0.0028811205338980777,
#  'Lithuania': 0.00247705524111763,
#  'LTTE (Sri Lanka)*': 0.005834862903043006,
#  'MTA (Myanmar)*': 0.0037496136804818373,
#  'Zambia': 0.005721193536490733,
#  'Uzbekistan': 0.0017991482414283252,
#  'Ukraine': 0.0021702486470824784,
#  'Tanzania': 0.002484010975193885,
#  'Taiwan': 0.00314663011799529,
#  'Switzerland': 0.0021919566515232842,
#  'South Yemen': 0.0028515762513483117,
#  'South Africa': 0.0034118271745602023,
#  'North Yemen': 0.0028209800734149914,
#  'Kenya': 0.003133620588072626,
#  'Kazakhstan': 0.002157125648179119,
#  'Ireland': 0.002440289354744115,
#  'Haiti': 0.0029435890365835564,
#  'Guatemala': 0.004825806493053192,
#  'Finland': 0.003789429783765955,
#  'Cuba': 0.002577492264297966,
#  'Croatia': 0.0022725657288587666,
#  'African Union**': 0.0018670947831240523,
#  'El Salvador': 0.00276311654959995,
#  'Mauritius': 0.0030316865938396394,
#  'Viet Minh (France)*': 0.0017064329665152532,
#  'United Wa State (Myanmar)*': 0.0017130159487742515,
#  'South Sudan': 0.00325976406988648,
#  'Somalia': 0.004762920790306843,
#  'Slovakia': 0.0018383407804277384,
#  'Seychelles': 0.0029803205339634362,
#  'North Korea': 0.0023676145654033132,
#  'Mujahedin (Afghanistan)*': 0.0018571239049947293,
#  'Kyrgyzstan': 0.001839687404763052,
#  'Khmer Rouge (Cambodia)*': 0.0017207277938960386,
#  'Guinea': 0.003251883882469025,
#  'Gambia': 0.002474948945017553,
#  'FNLA (Angola)*': 0.0017064329665152532,
#  'Equatorial Guinea': 0.001914401889613221,
#  'Central African Republic': 0.0022520870504698217,
#  'Burundi': 0.0018604313747610536,
#  'Costa Rica': 0.00369611440800542,
#  'Russia': 0.002004671302603831,
#  'Czechoslovakia': 0.0023301634756159374,
#  'East Germany (GDR)': 0.002435075894239548,
#  'Iceland': 0.0018836524502915742,
#  'PLO (Israel)*': 0.0021976737984139303,
#  'Yemen Arab Republic': 0.001777705315509894,
#  'Palestine': 0.002310756357912548,
#  'UIC (Somalia)*': 0.0025385067220322624,
#  'SNA (Somalia)*': 0.0025385067220322624,
#  'Europe multi-state': 0.0017038623514746575,
#  'European Union**': 0.0017038623514746575,
#  'FMLN (El Salvador)*': 0.003737781074855855,
#  'UNITA (Angola)*': 0.0017122078435831635,
#  'South Vietnam': 0.0022733627186622874,
#  'Malawi': 0.0018700383401907075,
#  'Madagascar': 0.0019445190609306102,
#  'Biafra': 0.0017744000348047333,
#  'Bhutan': 0.0019683695295372758,
#  'Malta': 0.003288403330605362,
#  'Luxembourg': 0.001778332539392379,
#  'Maldives': 0.007853821086899627,
#  'Houthi rebels (Yemen)*': 0.0018704829814857403,
#  'Hezbollah (Lebanon)*': 0.004447612713668064,
#  'LF (Lebanon)*': 0.004836264464961477,
#  'SLA (Lebanon)*': 0.0017694781461755394,
#  'Eswatini': 0.0018859974451947727,
#  'Provisional IRA (UK)*': 0.0018919614427585505,
#  'MNLF (Philippines)*': 0.001797911897116604,
#  'GUNT (Chad)*': 0.0019860109884004967,
#  'Darfur rebels (Sudan)*': 0.004188295309296488,
#  'Moldova': 0.0018615237014143818,
#  'Barbados': 0.0017150619156623469,
#  'PRC (Israel/Palestine)*': 0.0017476047417285907,
#  'Hamas (Palestine)*': 0.001767353688505585,
#  'Mongolia': 0.0018542146753094356,
#  'NTC (Libya)*': 0.002029945586691408,
#  'Liberia': 0.006987096041475405,
#  'Ukraine Rebels*': 0.0017098996446601627,
#  'Northern Alliance (Afghanistan)*': 0.0017249928776239259,
#  'Northern Cyprus': 0.0017385867158146097,
#  'ZAPU (Zimbabwe)*': 0.0017141493284156882,
#  'Viet Cong (South Vietnam)*': 0.002717625438601556,
#  'Pathet Lao (Laos)*': 0.0017131223381797389,
#  'Grenada': 0.0017057143488156737,
#  'ANC (South Africa)*': 0.0017057143488156737,
#  'Unknown country': 0.001722310655495789,
#  'Amal (Lebanon)*': 0.0028342879137402805,
#  'Lebanon Palestinian rebels*': 0.0019431134284457784,
#  'ELF (Ethiopia)*': 0.001929947463927782,
#  'Libya GNC': 0.0018693909723426193,
#  'Syria rebels*': 0.0017640626156980766,
#  'Kosovo': 0.0017415903076816303,
#  'RUF (Sierra Leone)*': 0.001712949197667542,
#  'Belize': 0.0017193451195841878,
#  'Saint Vincent': 0.0017052240320943833,
#  'Saint Kitts and Nevis': 0.0017052240320943833,
#  'Regional Security System**': 0.0017052240320943833,
#  'Indonesia rebels*': 0.0017052240320943833,
#  'Haiti rebels*': 0.0017052240320943833,
#  'Contras (Nicaragua)*': 0.0017161174770521904,
#  'Armas (Guatemala)*': 0.0017133941158127386,
#  'Anti-Castro rebels (Cuba)*': 0.0017052240320943833,
#  'Unknown supplier(s)': 0.0017038623514746575,
#  'Unknown rebel group*': 0.0017236112982516518,
#  'SPLA (Sudan)*': 0.0017104453337336556,
#  'RPF (Rwanda)*': 0.0017104453337336556,
#  'PKK (Turkey)*': 0.0017170283159926537,
#  'PIJ (Israel/Palestine)*': 0.0017104453337336556,
#  'PAIGC (Portugal)*': 0.0017104453337336556,
#  'NLA (Macedonia)*': 0.0017104453337336556,
#  'MPLA (Portugal)*': 0.0017104453337336556,
#  'LRA (Uganda)*': 0.0017104453337336556,
#  'FRELIMO (Portugal)*': 0.0017104453337336556,
#  'FAN (Chad)*': 0.0017104453337336556,
#  'EPLF (Ethiopia)*': 0.0017104453337336556}

# %%
max_pagerank_node_label = G.nodes[max(pagerank, key=pagerank.get)]['label']

max_pagerank_node_label

top_3_pagerank = sorted(pagerank, key=pagerank.get, reverse=True)[:3]
top_3_pagerank_info = [(node, G.nodes[node]['label'], pagerank[node]) for node in top_3_pagerank]

max_pagerank_node_label, top_3_pagerank_info
# Out:
# ('Bolivia',
#  [(26, 'Bolivia', 0.01702980156336316),
#   (251, 'Uruguay', 0.0145407649873836),
#   (245, 'United States', 0.013795768205557666)])

# %% [markdown]
# between central

# %%
between_central= nx.betweenness_centrality(G)

between_central_labels = {G.nodes[node_id]['label']: rank for node_id, rank in between_central.items()}
between_central_labels
# Out:
# {'(multiple sellers)': 0.0,
#  'Brazil': 0.010692004150668536,
#  'Albania': 8.298629971633774e-06,
#  'Burkina Faso': 0.0,
#  'Algeria': 0.004360105496151428,
#  'Angola': 0.014573538482667635,
#  'Nigeria': 0.00029282430686831213,
#  'Western Sahara': 0.0,
#  'Congo': 0.0,
#  'Cote dIvoire': 0.00047232928104993345,
#  'Guinea-Bissau': 0.0,
#  'United States': 0.11581534061399061,
#  'Argentina': 0.0008378927516155533,
#  'Bolivia': 0.0,
#  'Colombia': 0.0037282822080842103,
#  'Denmark': 0.0064215280844349566,
#  'Ecuador': 0.00014737705931967943,
#  'Honduras': 0.0,
#  'Paraguay': 0.0,
#  'Spain': 0.015645000322416763,
#  'Sri Lanka': 0.0005341565000655911,
#  'Uruguay': 0.00010290215635013421,
#  'Armenia': 4.8008603141682986e-06,
#  'Sudan': 0.008107708999023305,
#  'Aruba': 0.0,
#  'Israel': 0.01235905280929025,
#  'Australia': 0.013044108563520222,
#  'Lesotho': 0.0,
#  'Yemen': 0.0,
#  'Vanuatu': 0.0,
#  'United Kingdom': 0.03612501682685533,
#  'Tuvalu': 0.0,
#  'Trinidad and Tobago': 0.0,
#  'Tonga': 0.0,
#  'Timor-Leste': 0.0,
#  'Thailand': 7.311663273505755e-05,
#  'Sweden': 0.011165158876474924,
#  'Solomon Islands': 0.0,
#  'Singapore': 0.013168495695397794,
#  'Samoa': 0.0,
#  'Philippines': 9.852773197611653e-05,
#  'Papua New Guinea': 0.0,
#  'Palau': 0.0,
#  'Pakistan': 0.008010148435629154,
#  'Oman': 0.0015168632034677318,
#  'New Zealand': 0.0009410484044481798,
#  'Netherlands': 0.004932119575214649,
#  'Nepal': 0.0,
#  'Micronesia': 0.0,
#  'Marshall Islands': 0.0,
#  'Malaysia': 0.005989671966108764,
#  'India': 0.007209475595089696,
#  'Jordan': 0.026146412499333513,
#  'Brunei': 0.0,
#  'Cambodia': 0.0034134116833736605,
#  'Canada': 0.011348825554822521,
#  'Chad': 0.0007673422237894684,
#  'Chile': 0.004664500463605518,
#  'Fiji': 0.0,
#  'Ghana': 0.0037018345978262835,
#  'Indonesia': 0.0033772452670100045,
#  'Iraq': 0.005352040133700704,
#  'Jamaica': 0.0,
#  'Japan': 0.0002263280574807534,
#  'Kiribati': 0.0,
#  'Kuwait': 0.00035513209206119143,
#  'Laos': 0.0,
#  'Austria': 0.006465517893804943,
#  'Italy': 0.005361968265342191,
#  'Yugoslavia': 0.001145103012644428,
#  'Venezuela': 0.00035881403708360474,
#  'Uganda': 0.0010113127085773876,
#  'Turkmenistan': 0.0,
#  'Tunisia': 0.0,
#  'Saudi Arabia': 0.005757322914784703,
#  'Poland': 0.011842826397729628,
#  'OSCE**': 0.0,
#  'Niger': 2.3741037610723057e-05,
#  'Myanmar': 0.0,
#  'Morocco': 0.0007651518501360626,
#  'Montenegro': 0.00019708005291269758,
#  'Libya': 0.011813400155855856,
#  'Latvia': 4.863986889565873e-06,
#  'Belgium': 0.0034385368587477416,
#  'Czechia': 0.01243098951754555,
#  'Greece': 0.0012054990711839115,
#  'Portugal': 0.0008796348571408263,
#  'Slovenia': 3.4111252466752773e-06,
#  'UAE': 0.00991089200169864,
#  'Bangladesh': 0.00018967768275948214,
#  'Botswana': 0.0,
#  'Egypt': 0.014794999923221464,
#  'France': 0.03579203248328982,
#  'Gabon': 6.324561932926953e-05,
#  'Germany': 0.008504482966055493,
#  'Iran': 0.0074117047202772795,
#  'Bahamas': 3.961809604118302e-05,
#  'Bahrain': 0.00046221395444340154,
#  'Belarus': 8.540953241920164e-05,
#  'Viet Nam': 0.001962807128560324,
#  'Syria': 0.00714316554029918,
#  'Sierra Leone': 0.0,
#  'Serbia': 0.0007749977094500373,
#  'Rwanda': 0.0,
#  'Peru': 0.022095597593250072,
#  'Libya HoR': 0.001685101970273073,
#  'Afghanistan': 0.0,
#  'Azerbaijan': 0.0,
#  'China': 0.016687969192188134,
#  'Djibouti': 0.0,
#  'DR Congo': 0.013939503735261215,
#  'Eritrea': 0.003410337006517442,
#  'Ethiopia': 0.0017729901069888825,
#  'Hungary': 0.001838978225047706,
#  'Zimbabwe': 0.007461709606017238,
#  'United Nations**': 3.6140175502472536e-05,
#  'Turkey': 0.009575648998934915,
#  'Qatar': 0.0019327112033867902,
#  'Panama': 0.00017202823263475783,
#  'Norway': 0.0015283656336468835,
#  'NATO**': 0.0,
#  'Mexico': 0.010436010654706998,
#  'Lebanon': 0.0005529761940848917,
#  'Katanga': 0.0,
#  'Benin': 0.0,
#  'Bulgaria': 0.0058215269204051024,
#  'Estonia': 5.076982210823416e-05,
#  'Bosnia-Herzegovina': 0.00013921747524409122,
#  'Cameroon': 0.0,
#  'Comoros': 0.0,
#  'Unknown recipient(s)': 0.0,
#  'Togo': 0.0,
#  'Suriname': 0.0,
#  'South Korea': 0.0031272992426353992,
#  'Namibia': 0.0,
#  'Mozambique': 3.512470856513647e-05,
#  'Mauritania': 0.0,
#  'Mali': 0.0,
#  'Guyana': 0.008842785666032615,
#  'Dominican Republic': 1.7763183162422704e-05,
#  'Cyprus': 0.00014413547774537423,
#  'Cabo Verde': 0.0,
#  'Georgia': 0.0006228965529477497,
#  'Tajikistan': 0.0,
#  'Soviet Union': 0.021597217837574827,
#  'Southern rebels (Yemen)*': 0.0,
#  'Senegal': 0.00015827197135982407,
#  'Romania': 0.0040145524853023515,
#  'Nicaragua': 0.01284848818159155,
#  'Macedonia': 0.0,
#  'Lithuania': 1.7141664957894805e-05,
#  'LTTE (Sri Lanka)*': 0.0,
#  'MTA (Myanmar)*': 0.0,
#  'Zambia': 0.00015752641055095248,
#  'Uzbekistan': 0.0001746365454281361,
#  'Ukraine': 0.007420744633736755,
#  'Tanzania': 0.0,
#  'Taiwan': 0.0012530414939191303,
#  'Switzerland': 0.0032000255249245825,
#  'South Yemen': 0.0007555655423580725,
#  'South Africa': 0.011036652988763855,
#  'North Yemen': 3.6006452356262243e-06,
#  'Kenya': 0.00022778079097666306,
#  'Kazakhstan': 0.0014653715373615752,
#  'Ireland': 6.003469483242302e-05,
#  'Haiti': 0.0,
#  'Guatemala': 0.003777732440036529,
#  'Finland': 0.004738529857978033,
#  'Cuba': 0.00018977785023107402,
#  'Croatia': 0.0002134018671200742,
#  'African Union**': 0.0,
#  'El Salvador': 0.0,
#  'Mauritius': 0.0,
#  'Viet Minh (France)*': 0.0,
#  'United Wa State (Myanmar)*': 0.0,
#  'South Sudan': 0.0,
#  'Somalia': 0.0,
#  'Slovakia': 0.0021676062173444717,
#  'Seychelles': 0.00017085858988727983,
#  'North Korea': 0.004028041361378231,
#  'Mujahedin (Afghanistan)*': 9.241224992050121e-05,
#  'Kyrgyzstan': 0.000636584801505138,
#  'Khmer Rouge (Cambodia)*': 0.0,
#  'Guinea': 0.0,
#  'Gambia': 0.0,
#  'FNLA (Angola)*': 0.0,
#  'Equatorial Guinea': 0.0,
#  'Central African Republic': 0.0,
#  'Burundi': 0.0,
#  'Costa Rica': 0.004035120063354027,
#  'Russia': 0.009153234354047687,
#  'Czechoslovakia': 0.0010000910857290077,
#  'East Germany (GDR)': 0.00021553913748168326,
#  'Iceland': 0.0,
#  'PLO (Israel)*': 0.0,
#  'Yemen Arab Republic': 0.0,
#  'Palestine': 0.0,
#  'UIC (Somalia)*': 0.0,
#  'SNA (Somalia)*': 0.0,
#  'Europe multi-state': 0.0,
#  'European Union**': 0.0,
#  'FMLN (El Salvador)*': 0.0,
#  'UNITA (Angola)*': 0.0,
#  'South Vietnam': 6.504173066610529e-05,
#  'Malawi': 9.445087915260528e-05,
#  'Madagascar': 0.0,
#  'Biafra': 0.0,
#  'Bhutan': 0.0,
#  'Malta': 2.406161453862802e-05,
#  'Luxembourg': 2.8023121290846636e-06,
#  'Maldives': 0.0,
#  'Houthi rebels (Yemen)*': 0.0,
#  'Hezbollah (Lebanon)*': 0.0,
#  'LF (Lebanon)*': 0.0,
#  'SLA (Lebanon)*': 0.0,
#  'Eswatini': 0.0,
#  'Provisional IRA (UK)*': 0.0,
#  'MNLF (Philippines)*': 0.0,
#  'GUNT (Chad)*': 0.0,
#  'Darfur rebels (Sudan)*': 0.0,
#  'Moldova': 0.0002178031079075835,
#  'Barbados': 0.0,
#  'PRC (Israel/Palestine)*': 0.0,
#  'Hamas (Palestine)*': 0.0,
#  'Mongolia': 0.0,
#  'NTC (Libya)*': 0.0,
#  'Liberia': 0.0,
#  'Ukraine Rebels*': 0.0,
#  'Northern Alliance (Afghanistan)*': 0.0,
#  'Northern Cyprus': 0.0,
#  'ZAPU (Zimbabwe)*': 0.0,
#  'Viet Cong (South Vietnam)*': 0.0,
#  'Pathet Lao (Laos)*': 0.0,
#  'Grenada': 0.0,
#  'ANC (South Africa)*': 0.0,
#  'Unknown country': 0.0,
#  'Amal (Lebanon)*': 0.0,
#  'Lebanon Palestinian rebels*': 0.0,
#  'ELF (Ethiopia)*': 0.0,
#  'Libya GNC': 0.0,
#  'Syria rebels*': 0.0,
#  'Kosovo': 0.0,
#  'RUF (Sierra Leone)*': 0.0,
#  'Belize': 0.0,
#  'Saint Vincent': 0.0,
#  'Saint Kitts and Nevis': 0.0,
#  'Regional Security System**': 0.0,
#  'Indonesia rebels*': 0.0,
#  'Haiti rebels*': 0.0,
#  'Contras (Nicaragua)*': 0.0,
#  'Armas (Guatemala)*': 0.0,
#  'Anti-Castro rebels (Cuba)*': 0.0,
#  'Unknown supplier(s)': 0.0,
#  'Unknown rebel group*': 0.0,
#  'SPLA (Sudan)*': 0.0,
#  'RPF (Rwanda)*': 0.0,
#  'PKK (Turkey)*': 0.0,
#  'PIJ (Israel/Palestine)*': 0.0,
#  'PAIGC (Portugal)*': 0.0,
#  'NLA (Macedonia)*': 0.0,
#  'MPLA (Portugal)*': 0.0,
#  'LRA (Uganda)*': 0.0,
#  'FRELIMO (Portugal)*': 0.0,
#  'FAN (Chad)*': 0.0,
#  'EPLF (Ethiopia)*': 0.0}

# %%
max_between_central_label = G.nodes[max(between_central, key=between_central.get)]['label']

top_3_between_central = sorted(between_central, key=between_central.get, reverse=True)[:3]
top_3_between_central_info = [(node, G.nodes[node]['label'], between_central[node]) for node in top_3_between_central]

max_between_central_label, top_3_between_central_info
# Out:
# ('United States',
#  [(245, 'United States', 0.11581534061399061),
#   (243, 'United Kingdom', 0.03612501682685533),
#   (77, 'France', 0.03579203248328982)])

# %%
neo4j_conn = Neo4jConnection(uri="bolt://localhost:7687/", user="neo4j", pwd="zxysxtc233")

query = """
MATCH (n)-[r]->(m)
WHERE r.delivery_year >= '1950' AND r.delivery_year <= '1959'
RETURN n.name AS Source, m.name AS Target
"""
results = neo4j_conn.query(query)

csv_file_path = "graph_data/1950s.csv"

csv_dir = os.path.dirname(csv_file_path)

if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Source", "Target"])  # 写入表头
    
    for record in results:
        writer.writerow([record["Source"], record["Target"]])

neo4j_conn.close()

# %%
neo4j_conn = Neo4jConnection(uri="bolt://localhost:7687/", user="neo4j", pwd="zxysxtc233")

query = """
MATCH (n)-[r]->(m)
WHERE r.delivery_year >= '2010' AND r.delivery_year <= '2019'
RETURN n.name AS Source, m.name AS Target
"""
results = neo4j_conn.query(query)

csv_file_path = "graph_data/2010s.csv"

csv_dir = os.path.dirname(csv_file_path)

if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Source", "Target"])  # 写入表头
    
    for record in results:
        writer.writerow([record["Source"], record["Target"]])

neo4j_conn.close()

# %%
neo4j_conn = Neo4jConnection(uri="bolt://localhost:7687/", user="neo4j", pwd="zxysxtc233")

query = """
MATCH (n)-[r]->(m)
WHERE n.name = 'China' or m.name = 'China'
RETURN n.name AS Source, m.name AS Target
"""
results = neo4j_conn.query(query)

csv_file_path = "graph_data/China.csv"

csv_dir = os.path.dirname(csv_file_path)

if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Source", "Target"])  # 写入表头
    
    for record in results:
        writer.writerow([record["Source"], record["Target"]])

neo4j_conn.close()

# %%
neo4j_conn = Neo4jConnection(uri="bolt://localhost:7687/", user="neo4j", pwd="zxysxtc233")

query = """
MATCH (n)-[r]->(m)
WHERE m.name = 'China' 
RETURN n.name AS Source, m.name AS Target
"""
results = neo4j_conn.query(query)

csv_file_path = "graph_data/to_China.csv"

csv_dir = os.path.dirname(csv_file_path)

if not os.path.exists(csv_dir):
    os.makedirs(csv_dir)

with open(csv_file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Source", "Target"])  # 写入表头
    
    for record in results:
        writer.writerow([record["Source"], record["Target"]])

neo4j_conn.close()
